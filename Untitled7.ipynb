# %% [markdown]
# <a href="https://colab.research.google.com/github/tyagiji84/INITIAL_CODES/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 3

# %%
print("Unique species values:", df['species'].unique())
# Out:
# Unique species values: ['setosa' 'versicolor' 'virginica']

# %%
print("Cleaned dataset shape:", df.shape)
# Out:
# Cleaned dataset shape: (147, 5)

# %% [markdown]
# task2

# %%
df = pd.read_csv("him.csv")

# %%
numerical_cols = ['Retweets', 'Likes', 'Year', 'Month', 'Day', 'Hour']

# %%
basic_stats = df[numerical_cols].agg(['mean', 'median', 'std'])

# %%
modes = df[numerical_cols].mode().iloc[0]

# %%
basic_stats.loc['mode'] = modes

# %%
print(basic_stats)
# Out:
#          Retweets      Likes         Year     Month        Day       Hour
# mean    21.508197  42.901639  2020.471311  6.122951  15.497268  15.521858
# median  22.000000  43.000000  2021.000000  6.000000  15.000000  16.000000
# std      7.061286  14.089848     2.802285  3.411763   8.474553   4.113414
# mode    22.000000  45.000000  2023.000000  2.000000  15.000000  14.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("him.csv")

# %%
sns.set(style="whitegrid")

# %%
numerical_cols = ['Retweets', 'Likes', 'Year', 'Month', 'Day', 'Hour']

# %%
plt.figure(figsize=(16, 12))

# %%
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(df[col], kde=True, bins=20, color='skyblue')
    plt.title(f'Histogram of {col}')

# %%
sns.pairplot(df[numerical_cols])
plt.suptitle("Scatter Plot Matrix", y=1.02)
plt.show()

# %%
corr_matrix = df[numerical_cols].corr()

# %%
print("Correlation Matrix:")
print(corr_matrix)
# Out:
# Correlation Matrix:
#           Retweets     Likes      Year     Month       Day      Hour
# Retweets  1.000000  0.998482 -0.039982  0.073265  0.009213  0.196955
# Likes     0.998482  1.000000 -0.043415  0.066643  0.011489  0.195331
# Year     -0.039982 -0.043415  1.000000 -0.314845  0.021973 -0.087470
# Month     0.073265  0.066643 -0.314845  1.000000 -0.135873  0.137835
# Day       0.009213  0.011489  0.021973 -0.135873  1.000000  0.044072
# Hour      0.196955  0.195331 -0.087470  0.137835  0.044072  1.000000

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# task 3
# bar plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv("him.csv")


monthly_avg_likes = df.groupby('Month')['Likes'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=monthly_avg_likes, x='Month', y='Likes', palette='Blues')
plt.title('Average Likes per Month')
plt.ylabel('Average Likes')
plt.xlabel('Month')
plt.show()
# Out:
# <ipython-input-27-f8f60ed8ada8>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_avg_likes, x='Month', y='Likes', palette='Blues')

# %% [markdown]
# line chart

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])


daily_retweets = df.groupby('Date')['Retweets'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_retweets, x='Date', y='Retweets')
plt.title('Total Retweets Over Time')
plt.ylabel('Retweets')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter Plot

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Retweets', y='Likes')
plt.title('Scatter Plot of Likes vs Retweets')
plt.xlabel('Retweets')
plt.ylabel('Likes')
plt.show()

# %% [markdown]
# bar Plot with custom labels & title

# %%
sns.barplot(x='Month', y='Likes', data=df)
plt.title("Average Likes by Month", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Likes")
# Out:
# Text(0, 0.5, 'Likes')

# %% [markdown]
#  Line Plot (with legend

# %%
df = pd.read_csv("him.csv")


df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

daily_data = df.groupby('Date')[['Likes', 'Retweets']].sum().reset_index()


plt.figure(figsize=(10, 5))
plt.plot(daily_data['Date'], daily_data['Likes'], label='Likes')
plt.plot(daily_data['Date'], daily_data['Retweets'], label='Retweets')
plt.title("Likes & Retweets Over Time")
plt.xlabel("Date")
plt.ylabel("Count")
plt.legend(title="Metric")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter Plot (with hue legend)

# %%
sns.scatterplot(x='Retweets', y='Likes', data=df, hue='Hour')
plt.title("Likes vs Retweets by Hour")
plt.xlabel("Retweets")
plt.ylabel("Likes")
# Out:
# Text(0, 0.5, 'Likes')

# %% [markdown]
# Export plots as images for reports.

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])
daily_data = df.groupby('Date')[['Likes', 'Retweets']].sum().reset_index()

plt.figure(figsize=(10, 5))
plt.plot(daily_data['Date'], daily_data['Likes'], label='Likes')
plt.plot(daily_data['Date'], daily_data['Retweets'], label='Retweets')
plt.title("Likes & Retweets Over Time")
plt.xlabel("Date")
plt.ylabel("Count")
plt.legend(title="Metric")
plt.xticks(rotation=45)
plt.tight_layout()


plt.savefig("likes_retweets_over_time.png", dpi=300, bbox_inches='tight')
plt.show()
